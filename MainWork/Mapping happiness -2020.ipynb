# %%
# blanket import modules
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import pprint
from scipy.stats import linregress
import requests
import gmaps
import gmaps.geojson_geometries
from api_key import g_key
from matplotlib.colors import to_hex
from matplotlib.cm import inferno
#api key
gmaps.configure(api_key=g_key)

# %%
happy_cs = "Output/multiple_year_data.csv"

# %%
happy_df = pd.read_csv(happy_cs)
#trying to use this at the end 
happy_country=happy_df['Country']
happy_df
# Out:
#           Country  2022 Rank  2022 Happiness Score  2021 Rank  \
# 0         Finland          1                  7.82          1
# 1         Denmark          2                  7.64          2
# 2         Iceland          3                  7.56          4
# 3     Switzerland          4                  7.51          3
# 4     Netherlands          5                  7.42          5
# ..            ...        ...                   ...        ...
# 112      Tanzania        139                  3.70        142
# 113  Sierra Leone        140                  3.57        138
# 114      Zimbabwe        144                  3.00        148
# 115       Lebanon        145                  2.96        123
# 116   Afghanistan        146                  2.40        149
#
#      2021 Happiness Score  2020 Rank  2020 Happiness Score  2019 Rank  \
# 0                    7.84          1                  7.81          1
# 1                    7.62          2                  7.65          2
# 2                    7.55          4                  7.50          4
# 3                    7.57          3                  7.56          6
# 4                    7.46          6                  7.45          5
# ..                    ...        ...                   ...        ...
# 112                  3.62        148                  3.48        153
# 113                  3.85        139                  3.93        129
# 114                  3.14        151                  3.30        146
# 115                  4.58        111                  4.77         91
# 116                  2.52        153                  2.57        154
#
#      2019 Happiness Score  2018 Rank  2018 Happiness Score  2017 Rank  \
# 0                    7.77          1                  7.63          5
# 1                    7.60          3                  7.56          2
# 2                    7.49          4                  7.50          3
# 3                    7.48          5                  7.49          4
# 4                    7.49          6                  7.44          6
# ..                    ...        ...                   ...        ...
# 112                  3.23        153                  3.30        153
# 113                  4.37        113                  4.57        106
# 114                  3.66        144                  3.69        138
# 115                  5.20         80                  5.36         88
# 116                  3.20        145                  3.63        141
#
#      2017 Happiness Score  2016 Rank  2016 Happiness Score  2015 Rank  \
# 0                    7.47          5                  7.41          6
# 1                    7.52          1                  7.53          3
# 2                    7.50          3                  7.50          2
# 3                    7.49          2                  7.51          1
# 4                    7.38          7                  7.34          7
# ..                    ...        ...                   ...        ...
# 112                  3.35        149                  3.67        146
# 113                  4.71        111                  4.64        123
# 114                  3.88        131                  4.19        115
# 115                  5.22         93                  5.13        103
# 116                  3.79        154                  3.36        153
#
#      2015 Happiness Score
# 0                    7.41
# 1                    7.53
# 2                    7.56
# 3                    7.59
# 4                    7.38
# ..                    ...
# 112                  3.78
# 113                  4.51
# 114                  4.61
# 115                  4.84
# 116                  3.58
#
# [117 rows x 17 columns]

# %%
#making initial map with lines around country to fill later
countries_geojson = gmaps.geojson_geometries.load_geometry('countries')
fig = gmaps.figure()
happy_layer=gmaps.geojson_layer(countries_geojson)
# fig.add_layer(happy_layer)
# fig

# %%
# need to get the min and the max of happiness
# happy_df=happy_df.set_index(["Country"])

# %%
# happy_df.dtypes

# %%
happy_col=happy_df["2020 Happiness Score"]
h_range=[]

for x in happy_col:
    happ_conv= x / 10
    h_range.append(happ_conv)
    
# happy_range=happ_max-happ_min

happy_df['Happiness Range 2020'] = h_range
happy_df
# happy_df["Country"].values
# Out:
#           Country  2022 Rank  2022 Happiness Score  2021 Rank  \
# 0         Finland          1                  7.82          1
# 1         Denmark          2                  7.64          2
# 2         Iceland          3                  7.56          4
# 3     Switzerland          4                  7.51          3
# 4     Netherlands          5                  7.42          5
# ..            ...        ...                   ...        ...
# 112      Tanzania        139                  3.70        142
# 113  Sierra Leone        140                  3.57        138
# 114      Zimbabwe        144                  3.00        148
# 115       Lebanon        145                  2.96        123
# 116   Afghanistan        146                  2.40        149
#
#      2021 Happiness Score  2020 Rank  2020 Happiness Score  2019 Rank  \
# 0                    7.84          1                  7.81          1
# 1                    7.62          2                  7.65          2
# 2                    7.55          4                  7.50          4
# 3                    7.57          3                  7.56          6
# 4                    7.46          6                  7.45          5
# ..                    ...        ...                   ...        ...
# 112                  3.62        148                  3.48        153
# 113                  3.85        139                  3.93        129
# 114                  3.14        151                  3.30        146
# 115                  4.58        111                  4.77         91
# 116                  2.52        153                  2.57        154
#
#      2019 Happiness Score  2018 Rank  2018 Happiness Score  2017 Rank  \
# 0                    7.77          1                  7.63          5
# 1                    7.60          3                  7.56          2
# 2                    7.49          4                  7.50          3
# 3                    7.48          5                  7.49          4
# 4                    7.49          6                  7.44          6
# ..                    ...        ...                   ...        ...
# 112                  3.23        153                  3.30        153
# 113                  4.37        113                  4.57        106
# 114                  3.66        144                  3.69        138
# 115                  5.20         80                  5.36         88
# 116                  3.20        145                  3.63        141
#
#      2017 Happiness Score  2016 Rank  2016 Happiness Score  2015 Rank  \
# 0                    7.47          5                  7.41          6
# 1                    7.52          1                  7.53          3
# 2                    7.50          3                  7.50          2
# 3                    7.49          2                  7.51          1
# 4                    7.38          7                  7.34          7
# ..                    ...        ...                   ...        ...
# 112                  3.35        149                  3.67        146
# 113                  4.71        111                  4.64        123
# 114                  3.88        131                  4.19        115
# 115                  5.22         93                  5.13        103
# 116                  3.79        154                  3.36        153
#
#      2015 Happiness Score  Happiness Range 2021  Happiness Range 2020
# 0                    7.41                 0.781                 0.781
# 1                    7.53                 0.765                 0.765
# 2                    7.56                 0.750                 0.750
# 3                    7.59                 0.756                 0.756
# 4                    7.38                 0.745                 0.745
# ..                    ...                   ...                   ...
# 112                  3.78                 0.348                 0.348
# 113                  4.51                 0.393                 0.393
# 114                  4.61                 0.330                 0.330
# 115                  4.84                 0.477                 0.477
# 116                  3.58                 0.257                 0.257
#
# [117 rows x 19 columns]

# %%
# We will need to scale the Happiness values to lie between 0 and 1, this sets up for color ranges below
happ_max1=happy_df["Happiness Range 2020"].max()
happ_min1=happy_df["Happiness Range 2020"].min()
hap_range=happ_max1-happ_min1
inferno2= inferno.reversed()

def calculate_color(h_range):
    
#     Convert the happiness coefficient to a color

    # make happiness score a number between 0 and 1
    normalized_range = (h_range - happ_min1) / hap_range

    # invert happiness so that high inequality gives dark color
    inverse_hap = 1.0 - normalized_range

    # transform the happiness coefficient to a matplotlib color
    mpl_color = inferno2(inverse_hap)

    # transform from a matplotlib color to a valid CSS color
    gmaps_color = to_hex(mpl_color, keep_alpha=False)

    return gmaps_color

# %%
colors = []
for feature in countries_geojson['features']:
    country_name = feature['properties']['name']
    print(country_name)
    try:
        h_range = happy_df.loc[happy_df["Country"]==country_name]["Happiness Range 2020"].values
        print(h_range)
        color = calculate_color(h_range)
        print(color)
    except KeyError:
        # no happyy score for that country: return default color
        color = (0, 0, 0, 0.3)
        print(country_name+" not available")
    except ValueError: 
        color = (0, 0, 0, 0.3)
        
    print(color)    
    colors.append(color)
colors
# Out:
# Afghanistan
# [0.257]
# #000004
# #000004
# Angola
# []
# (0, 0, 0, 0.3)
# Albania
# [0.488]
# #a32c61
# #a32c61
# Aland
# []
# (0, 0, 0, 0.3)
# Andorra
# []
# (0, 0, 0, 0.3)
# United Arab Emirates
# [0.679]
# #fca80d
# #fca80d
# Argentina
# [0.597]
# #ea632a
# #ea632a
# Armenia
# [0.468]
# #952667
# #952667
# American Samoa
# []
# (0, 0, 0, 0.3)
# Antarctica
# []
# (0, 0, 0, 0.3)
# French Southern and Antarctic Lands
# []
# (0, 0, 0, 0.3)
# Antigua and Barbuda
# []
# (0, 0, 0, 0.3)
# Australia
# [0.722]
# #f7d13d
# #f7d13d
# Austria
# [0.729]
# #f6d746
# #f6d746
# Azerbaijan
# []
# (0, 0, 0, 0.3)
# Burundi
# []
# (0, 0, 0, 0.3)
# Belgium
# [0.686]
# #fcae12
# #fcae12
# Benin
# [0.522]
# #bd3853
# #bd3853
# Burkina Faso
# [0.477]
# #9b2964
# #9b2964
# Bangladesh
# [0.483]
# #a02a63
# #a02a63
# Bulgaria
# [0.51]
# #b43359
# #b43359
# Bahrain
# [0.623]
# #f3761b
# #f3761b
# The Bahamas
# []
# (0, 0, 0, 0.3)
# Bosnia and Herzegovina
# [0.567]
# #da4e3c
# #da4e3c
# Belarus
# []
# (0, 0, 0, 0.3)
# Belize
# []
# (0, 0, 0, 0.3)
# Bolivia
# [0.575]
# #df5337
# #df5337
# Brazil
# [0.638]
# #f78410
# #f78410
# Barbados
# []
# (0, 0, 0, 0.3)
# Brunei
# []
# (0, 0, 0, 0.3)
# Bhutan
# []
# (0, 0, 0, 0.3)
# Botswana
# []
# (0, 0, 0, 0.3)
# Central African Republic
# []
# (0, 0, 0, 0.3)
# Canada
# [0.723]
# #f7d13d
# #f7d13d
# Switzerland
# [0.756]
# #f1ef75
# #f1ef75
# Chile
# [0.623]
# #f3761b
# #f3761b
# China
# [0.512]
# #b63458
# #b63458
# Ivory Coast
# [0.523]
# #bd3853
# #bd3853
# Cameroon
# [0.508]
# #b3325a
# #b3325a
# Cyprus No Mans Area
# []
# (0, 0, 0, 0.3)
# Democratic Republic of the Congo
# []
# (0, 0, 0, 0.3)
# Republic of Congo
# []
# (0, 0, 0, 0.3)
# Colombia
# [0.616]
# #f1711f
# #f1711f
# Comoros
# []
# (0, 0, 0, 0.3)
# Cape Verde
# []
# (0, 0, 0, 0.3)
# Costa Rica
# [0.712]
# #f9c72f
# #f9c72f
# Cuba
# []
# (0, 0, 0, 0.3)
# Curaçao
# []
# (0, 0, 0, 0.3)
# Cayman Islands
# []
# (0, 0, 0, 0.3)
# Northern Cyprus
# []
# (0, 0, 0, 0.3)
# Cyprus
# [0.616]
# #f1711f
# #f1711f
# Czech Republic
# []
# (0, 0, 0, 0.3)
# Germany
# [0.708]
# #fac42a
# #fac42a
# Djibouti
# []
# (0, 0, 0, 0.3)
# Dominica
# []
# (0, 0, 0, 0.3)
# Denmark
# [0.765]
# #f3f68a
# #f3f68a
# Dominican Republic
# [0.569]
# #db503b
# #db503b
# Algeria
# [0.501]
# #ae305c
# #ae305c
# Ecuador
# [0.593]
# #e8602d
# #e8602d
# Egypt
# [0.415]
# #6c186e
# #6c186e
# Eritrea
# []
# (0, 0, 0, 0.3)
# Spain
# [0.64]
# #f8850f
# #f8850f
# Estonia
# [0.602]
# #eb6628
# #eb6628
# Ethiopia
# [0.419]
# #6f196e
# #6f196e
# Finland
# [0.781]
# #fcffa4
# #fcffa4
# Fiji
# []
# (0, 0, 0, 0.3)
# Falkland Islands
# []
# (0, 0, 0, 0.3)
# France
# [0.666]
# #fb9b06
# #fb9b06
# Faroe Islands
# []
# (0, 0, 0, 0.3)
# Federated States of Micronesia
# []
# (0, 0, 0, 0.3)
# Gabon
# [0.483]
# #a02a63
# #a02a63
# United Kingdom
# [0.716]
# #f9cb35
# #f9cb35
# Georgia
# [0.467]
# #932667
# #932667
# Ghana
# [0.515]
# #b93556
# #b93556
# Guinea
# [0.495]
# #a92e5e
# #a92e5e
# Gambia
# []
# (0, 0, 0, 0.3)
# Guinea Bissau
# []
# (0, 0, 0, 0.3)
# Equatorial Guinea
# []
# (0, 0, 0, 0.3)
# Greece
# [0.551]
# #d04545
# #d04545
# Grenada
# []
# (0, 0, 0, 0.3)
# Greenland
# []
# (0, 0, 0, 0.3)
# Guatemala
# []
# (0, 0, 0, 0.3)
# Guam
# []
# (0, 0, 0, 0.3)
# Guyana
# []
# (0, 0, 0, 0.3)
# Hong Kong S.A.R.
# []
# (0, 0, 0, 0.3)
# Heard Island and McDonald Islands
# []
# (0, 0, 0, 0.3)
# Honduras
# [0.595]
# #e9612b
# #e9612b
# Croatia
# [0.55]
# #d04545
# #d04545
# Haiti
# []
# (0, 0, 0, 0.3)
# Hungary
# [0.6]
# #eb6429
# #eb6429
# Indonesia
# [0.529]
# #c13a50
# #c13a50
# Isle of Man
# []
# (0, 0, 0, 0.3)
# India
# [0.357]
# #3d0965
# #3d0965
# Ireland
# [0.709]
# #fac42a
# #fac42a
# Iran
# [0.467]
# #932667
# #932667
# Iraq
# [0.478]
# #9b2964
# #9b2964
# Iceland
# [0.75]
# #f2ea69
# #f2ea69
# Israel
# [0.713]
# #f9c72f
# #f9c72f
# Italy
# [0.639]
# #f78410
# #f78410
# Jamaica
# [0.589]
# #e65d2f
# #e65d2f
# Jordan
# [0.463]
# #902568
# #902568
# Japan
# [0.587]
# #e55c30
# #e55c30
# Baykonur Cosmodrome
# []
# (0, 0, 0, 0.3)
# Siachen Glacier
# []
# (0, 0, 0, 0.3)
# Kazakhstan
# [0.606]
# #ed6925
# #ed6925
# Kenya
# [0.458]
# #8d2369
# #8d2369
# Kyrgyzstan
# [0.554]
# #d34743
# #d34743
# Cambodia
# [0.485]
# #a22b62
# #a22b62
# Kiribati
# []
# (0, 0, 0, 0.3)
# Saint Kitts and Nevis
# []
# (0, 0, 0, 0.3)
# South Korea
# [0.587]
# #e55c30
# #e55c30
# Kosovo
# [0.633]
# #f67e14
# #f67e14
# Kuwait
# []
# (0, 0, 0, 0.3)
# Laos
# []
# (0, 0, 0, 0.3)
# Lebanon
# [0.477]
# #9b2964
# #9b2964
# Liberia
# []
# (0, 0, 0, 0.3)
# Libya
# []
# (0, 0, 0, 0.3)
# Saint Lucia
# []
# (0, 0, 0, 0.3)
# Liechtenstein
# []
# (0, 0, 0, 0.3)
# Sri Lanka
# [0.433]
# #781c6d
# #781c6d
# Lesotho
# []
# (0, 0, 0, 0.3)
# Lithuania
# [0.622]
# #f3761b
# #f3761b
# Luxembourg
# []
# (0, 0, 0, 0.3)
# Latvia
# [0.595]
# #e9612b
# #e9612b
# Morocco
# [0.509]
# #b43359
# #b43359
# Moldova
# [0.561]
# #d74b3f
# #d74b3f
# Madagascar
# []
# (0, 0, 0, 0.3)
# Mexico
# [0.647]
# #f98b0b
# #f98b0b
# Macedonia
# []
# (0, 0, 0, 0.3)
# Mali
# [0.473]
# #982766
# #982766
# Malta
# [0.677]
# #fca60c
# #fca60c
# Myanmar
# [0.431]
# #781c6d
# #781c6d
# Montenegro
# [0.555]
# #d34743
# #d34743
# Mongolia
# [0.546]
# #ce4347
# #ce4347
# Northern Mariana Islands
# []
# (0, 0, 0, 0.3)
# Mozambique
# []
# (0, 0, 0, 0.3)
# Mauritania
# []
# (0, 0, 0, 0.3)
# Mauritius
# [0.61]
# #ef6c23
# #ef6c23
# Malawi
# [0.354]
# #3b0964
# #3b0964
# Malaysia
# [0.538]
# #c83f4b
# #c83f4b
# Namibia
# []
# (0, 0, 0, 0.3)
# New Caledonia
# []
# (0, 0, 0, 0.3)
# Niger
# []
# (0, 0, 0, 0.3)
# Nigeria
# [0.472]
# #982766
# #982766
# Nicaragua
# [0.614]
# #f06f20
# #f06f20
# Niue
# []
# (0, 0, 0, 0.3)
# Netherlands
# [0.745]
# #f2e661
# #f2e661
# Norway
# [0.749]
# #f2ea69
# #f2ea69
# Nepal
# [0.514]
# #b73557
# #b73557
# New Zealand
# [0.73]
# #f5d949
# #f5d949
# Oman
# []
# (0, 0, 0, 0.3)
# Pakistan
# [0.569]
# #db503b
# #db503b
# Panama
# [0.63]
# #f57d15
# #f57d15
# Peru
# [0.58]
# #e15635
# #e15635
# Philippines
# [0.601]
# #eb6628
# #eb6628
# Palau
# []
# (0, 0, 0, 0.3)
# Papua New Guinea
# []
# (0, 0, 0, 0.3)
# Poland
# [0.619]
# #f1731d
# #f1731d
# Puerto Rico
# []
# (0, 0, 0, 0.3)
# North Korea
# []
# (0, 0, 0, 0.3)
# Portugal
# [0.591]
# #e75e2e
# #e75e2e
# Paraguay
# [0.569]
# #db503b
# #db503b
# Palestine
# []
# (0, 0, 0, 0.3)
# French Polynesia
# []
# (0, 0, 0, 0.3)
# Qatar
# []
# (0, 0, 0, 0.3)
# Romania
# [0.612]
# #ef6e21
# #ef6e21
# Russia
# [0.555]
# #d34743
# #d34743
# Rwanda
# []
# (0, 0, 0, 0.3)
# Western Sahara
# []
# (0, 0, 0, 0.3)
# Saudi Arabia
# [0.641]
# #f8850f
# #f8850f
# Sudan
# []
# (0, 0, 0, 0.3)
# South Sudan
# []
# (0, 0, 0, 0.3)
# Senegal
# [0.498]
# #ab2f5e
# #ab2f5e
# Singapore
# [0.638]
# #f78410
# #f78410
# South Georgia and South Sandwich Islands
# []
# (0, 0, 0, 0.3)
# Saint Helena
# []
# (0, 0, 0, 0.3)
# Solomon Islands
# []
# (0, 0, 0, 0.3)
# Sierra Leone
# [0.393]
# #5a116e
# #5a116e
# El Salvador
# [0.635]
# #f68013
# #f68013
# Somaliland
# []
# (0, 0, 0, 0.3)
# Somalia
# []
# (0, 0, 0, 0.3)
# Saint Pierre and Miquelon
# []
# (0, 0, 0, 0.3)
# Republic of Serbia
# []
# (0, 0, 0, 0.3)
# Sao Tome and Principe
# []
# (0, 0, 0, 0.3)
# Suriname
# []
# (0, 0, 0, 0.3)
# Slovakia
# [0.628]
# #f57b17
# #f57b17
# Slovenia
# [0.636]
# #f78212
# #f78212
# Sweden
# [0.735]
# #f4dd4f
# #f4dd4f
# Swaziland
# []
# (0, 0, 0, 0.3)
# Syria
# []
# (0, 0, 0, 0.3)
# Chad
# []
# (0, 0, 0, 0.3)
# Togo
# [0.419]
# #6f196e
# #6f196e
# Thailand
# [0.6]
# #eb6429
# #eb6429
# Tajikistan
# [0.556]
# #d44842
# #d44842
# Turkmenistan
# []
# (0, 0, 0, 0.3)
# East Timor
# []
# (0, 0, 0, 0.3)
# Tonga
# []
# (0, 0, 0, 0.3)
# Trinidad and Tobago
# []
# (0, 0, 0, 0.3)
# Tunisia
# [0.439]
# #7d1e6d
# #7d1e6d
# Turkey
# [0.513]
# #b73557
# #b73557
# Taiwan
# []
# (0, 0, 0, 0.3)
# United Republic of Tanzania
# []
# (0, 0, 0, 0.3)
# Uganda
# [0.443]
# #801f6c
# #801f6c
# Ukraine
# [0.456]
# #8c2369
# #8c2369
# Uruguay
# [0.644]
# #f8890c
# #f8890c
# United States of America
# [0.694]
# #fbb61a
# #fbb61a
# Uzbekistan
# [0.626]
# #f47918
# #f47918
# Saint Vincent and the Grenadines
# []
# (0, 0, 0, 0.3)
# Venezuela
# [0.505]
# #b1325a
# #b1325a
# United States Virgin Islands
# []
# (0, 0, 0, 0.3)
# Vietnam
# [0.535]
# #c63d4d
# #c63d4d
# Vanuatu
# []
# (0, 0, 0, 0.3)
# Samoa
# []
# (0, 0, 0, 0.3)
# Yemen
# []
# (0, 0, 0, 0.3)
# South Africa
# [0.481]
# #9f2a63
# #9f2a63
# Zambia
# [0.376]
# #4d0d6c
# #4d0d6c
# Zimbabwe
# [0.33]
# #260c51
# #260c51
# ['#000004',
#  (0, 0, 0, 0.3),
#  '#a32c61',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fca80d',
#  '#ea632a',
#  '#952667',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f7d13d',
#  '#f6d746',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fcae12',
#  '#bd3853',
#  '#9b2964',
#  '#a02a63',
#  '#b43359',
#  '#f3761b',
#  (0, 0, 0, 0.3),
#  '#da4e3c',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#df5337',
#  '#f78410',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f7d13d',
#  '#f1ef75',
#  '#f3761b',
#  '#b63458',
#  '#bd3853',
#  '#b3325a',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f1711f',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f9c72f',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f1711f',
#  (0, 0, 0, 0.3),
#  '#fac42a',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f3f68a',
#  '#db503b',
#  '#ae305c',
#  '#e8602d',
#  '#6c186e',
#  (0, 0, 0, 0.3),
#  '#f8850f',
#  '#eb6628',
#  '#6f196e',
#  '#fcffa4',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fb9b06',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#a02a63',
#  '#f9cb35',
#  '#932667',
#  '#b93556',
#  '#a92e5e',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#d04545',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#e9612b',
#  '#d04545',
#  (0, 0, 0, 0.3),
#  '#eb6429',
#  '#c13a50',
#  (0, 0, 0, 0.3),
#  '#3d0965',
#  '#fac42a',
#  '#932667',
#  '#9b2964',
#  '#f2ea69',
#  '#f9c72f',
#  '#f78410',
#  '#e65d2f',
#  '#902568',
#  '#e55c30',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#ed6925',
#  '#8d2369',
#  '#d34743',
#  '#a22b62',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#e55c30',
#  '#f67e14',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#9b2964',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#781c6d',
#  (0, 0, 0, 0.3),
#  '#f3761b',
#  (0, 0, 0, 0.3),
#  '#e9612b',
#  '#b43359',
#  '#d74b3f',
#  (0, 0, 0, 0.3),
#  '#f98b0b',
#  (0, 0, 0, 0.3),
#  '#982766',
#  '#fca60c',
#  '#781c6d',
#  '#d34743',
#  '#ce4347',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#ef6c23',
#  '#3b0964',
#  '#c83f4b',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#982766',
#  '#f06f20',
#  (0, 0, 0, 0.3),
#  '#f2e661',
#  '#f2ea69',
#  '#b73557',
#  '#f5d949',
#  (0, 0, 0, 0.3),
#  '#db503b',
#  '#f57d15',
#  '#e15635',
#  '#eb6628',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f1731d',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#e75e2e',
#  '#db503b',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#ef6e21',
#  '#d34743',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f8850f',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#ab2f5e',
#  '#f78410',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#5a116e',
#  '#f68013',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f57b17',
#  '#f78212',
#  '#f4dd4f',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#6f196e',
#  '#eb6429',
#  '#d44842',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#7d1e6d',
#  '#b73557',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#801f6c',
#  '#8c2369',
#  '#f8890c',
#  '#fbb61a',
#  '#f47918',
#  (0, 0, 0, 0.3),
#  '#b1325a',
#  (0, 0, 0, 0.3),
#  '#c63d4d',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#9f2a63',
#  '#4d0d6c',
#  '#260c51']

# %%
fig = gmaps.figure()
happy_layer2 = gmaps.geojson_layer(
    countries_geojson,
    fill_color=colors,
    stroke_color=colors,
    fill_opacity=0.8)
fig.add_layer(happy_layer2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
