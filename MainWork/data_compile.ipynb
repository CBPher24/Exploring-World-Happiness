# %%
# blanket import modules
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import pprint

out_csv = "Output/happy_comb-data.csv"

# %%
# setting up paths for data
happy_cs = "../Resources/World Happiness Report 2022.csv"
sunshine_cs = "../Resources/sunshine hours by city.csv"
income_js = "../Resources/Income.json"
alcohol_js = "../Resources/Alcohol.json"

# %%
# making data pandas readable
happy_df = pd.read_csv(happy_cs)
sunshine_df = pd.read_csv(sunshine_cs)
income_df = pd.read_json(income_js)
alcohol_df = pd.read_json(alcohol_js)

# %%
#Happiness Data peek
happy_df.head(2)
# Out:
#    RANK  Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1  Finland            7.821         7.886        7.756
# 1     2  Denmark            7.636         7.710        7.563
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# 1                         1.243                                  0.777
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.736                     0.109
# 1                                       0.719                     0.188
#
#    Explained by: Perceptions of corruption
# 0                                    0.534
# 1                                    0.532

# %%
#Sunshine Data peek
sunshine_df.head(2)
# Out:
#        Country    City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0  Afghanistan   Kabul  177.2  178.6  204.5  232.5  310.3  353.4  356.8
# 1      Albania  Tirana  124.0  125.0  165.0  191.0  263.0  298.0  354.0
#
#      Aug    Sep    Oct    Nov    Dec    Year
# 0  339.7  303.9  282.6  253.2  182.4  3175.1
# 1  327.0  264.0  218.0  127.0   88.0  2544.0

# %%
#Income Data peek
income_df.head(2)
# Out:
#                 country  medianIncome  meanIncome  gdpPerCapitaPPP    pop2022
# 0            Luxembourg         26321       31376           124590    642.371
# 1  United Arab Emirates         24292       27017            70089  10081.785

# %%
#Alcohol Data peek
alcohol_df.head(2)
# Out:
#    country   both   male  female
# 0   Latvia  13.19  21.61    6.31
# 1  Moldova  12.85  20.61    5.89

# %%
#calculating the avg sunshine for whole country then cutting just total
sun_ctry_df = sunshine_df.groupby("Country").mean().round(2)
sun_ctry_df.head(2)
# Out:
#                Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# Country
# Afghanistan  177.2  178.6  204.5  232.5  310.3  353.4  356.8  339.7  303.9
# Albania      124.0  125.0  165.0  191.0  263.0  298.0  354.0  327.0  264.0
#
#                Oct    Nov    Dec    Year
# Country
# Afghanistan  282.6  253.2  182.4  3175.1
# Albania      218.0  127.0   88.0  2544.0

# %%
#grabbing data needed for merge
sun_yrly = sun_ctry_df.loc[: , "Year"]
mean_inc = income_df.loc[: , ["country" , "meanIncome"]]
alc_cons = alcohol_df.loc[: , ["country" , "both"]]
happ_small = happy_df.loc[: , ["RANK", "Country", "Happiness score", "Explained by: Healthy life expectancy"]]

# %%
coun_merge = pd.merge(mean_inc,alc_cons, on="country")
coun_2_Coun = coun_merge.rename(columns={"country":"Country"})
sub_comb_data =  pd.merge(pd.merge(happ_small,sun_yrly, on="Country", how="left")
                        ,coun_2_Coun, on="Country", how="left").dropna()
sub_comb_data = sub_comb_data.rename(columns={"Year":"Sunshine hours per Year", "meanIncome":"Average Income", 
                              "both":"Alcohol Consumption (L/year)"})
sub_comb_data
# Out:
#      RANK      Country  Happiness score  \
# 0       1      Finland            7.821
# 1       2      Denmark            7.636
# 2       3      Iceland            7.557
# 3       4  Switzerland            7.512
# 4       5  Netherlands            7.415
# ..    ...          ...              ...
# 135   136        India            3.777
# 136   137       Zambia            3.760
# 137   138       Malawi            3.750
# 138   139     Tanzania            3.702
# 143   144     Zimbabwe            2.995
#
#      Explained by: Healthy life expectancy  Sunshine hours per Year  \
# 0                                    0.775                  1858.00
# 1                                    0.777                  1932.00
# 2                                    0.803                  1326.00
# 3                                    0.822                  1932.75
# 4                                    0.787                  1662.00
# ..                                     ...                      ...
# 135                                  0.471                  2517.02
# 136                                  0.306                  2965.47
# 137                                  0.388                  2795.87
# 138                                  0.425                  3032.85
# 143                                  0.270                  3065.40
#
#      Average Income  Alcohol Consumption (L/year)
# 0           18742.0                         10.65
# 1           20304.0                         10.13
# 2           19300.0                          9.21
# 3           25787.0                         11.23
# 4           19690.0                          9.67
# ..              ...                           ...
# 135          1314.0                          5.61
# 136          1045.0                          4.46
# 137           733.0                          4.08
# 138           992.0                         12.04
# 143          1429.0                          4.52
#
# [98 rows x 7 columns]

# %%
#output data to csv
happy_data = sub_comb_data.to_csv(out_csv, index=False)
