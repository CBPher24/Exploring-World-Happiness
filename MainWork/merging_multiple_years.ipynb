# %%
# blanket import modules
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import pprint

out_csv = "Output/multiple_year_data.csv"

# %%
# setting up paths for data
y2022_cs = "../Resources/World Happiness Report 2022.csv"
y2021_cs = "../Resources/2021.csv"
y2020_cs = "../Resources/2020.csv"
y2019_cs = "../Resources/2019.csv"
y2018_cs = "../Resources/2018.csv"
y2017_cs = "../Resources/2017.csv"
y2016_cs = "../Resources/2016.csv"
y2015_cs = "../Resources/2015.csv"

# %%
# making data pandas readable
y2022_df = pd.read_csv(y2022_cs)
y2021_df = pd.read_csv(y2021_cs)
y2020_df = pd.read_csv(y2020_cs)
y2019_df = pd.read_csv(y2019_cs)
y2018_df = pd.read_csv(y2018_cs)
y2017_df = pd.read_csv(y2017_cs)
y2016_df = pd.read_csv(y2016_cs)
y2015_df = pd.read_csv(y2015_cs)
y2016_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
#grabbing data needed for merge
y2022_df_e = y2022_df.loc[: , ["RANK", "Country", "Happiness score"]]
y2021_df_e = y2021_df.loc[: , ["Country name", "Ladder score"]]
y2020_df_e = y2020_df.loc[: , ["Country name", "Ladder score"]]
y2019_df_e = y2019_df.loc[: , ["Overall rank", "Country or region", "Score"]]
y2018_df_e = y2018_df.loc[: , ["Overall rank", "Country or region", "Score"]]
y2017_df_e = y2017_df.loc[: , ["Happiness.Rank", "Country", "Happiness.Score"]]
y2016_df_e = y2016_df.loc[: , ["Happiness Rank", "Country", "Happiness Score"]]
y2015_df_e = y2015_df.loc[: , ["Happiness Rank", "Country", "Happiness Score"]]

# %%
y2021_df_e
# Out:
#     Country name  Ladder score
# 0        Finland         7.842
# 1        Denmark         7.620
# 2    Switzerland         7.571
# 3        Iceland         7.554
# 4    Netherlands         7.464
# ..           ...           ...
# 144      Lesotho         3.512
# 145     Botswana         3.467
# 146       Rwanda         3.415
# 147     Zimbabwe         3.145
# 148  Afghanistan         2.523
#
# [149 rows x 2 columns]
