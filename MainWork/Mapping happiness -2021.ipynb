# %%
# blanket import modules
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import pprint
from scipy.stats import linregress
import requests
import gmaps
import gmaps.geojson_geometries
from api_key import g_key
from matplotlib.colors import to_hex
from matplotlib.cm import inferno
#api key
gmaps.configure(api_key=g_key)

# %%
happy_cs = "Output/multiple_year_data.csv"

# %%
happy_df = pd.read_csv(happy_cs)
#trying to use this at the end 
happy_country=happy_df['Country']
happy_df
# Out:
#           Country  2022 Rank  2022 Happiness Score  2021 Rank  \
# 0         Finland          1                  7.82          1
# 1         Denmark          2                  7.64          2
# 2         Iceland          3                  7.56          4
# 3     Switzerland          4                  7.51          3
# 4     Netherlands          5                  7.42          5
# ..            ...        ...                   ...        ...
# 112      Tanzania        139                  3.70        142
# 113  Sierra Leone        140                  3.57        138
# 114      Zimbabwe        144                  3.00        148
# 115       Lebanon        145                  2.96        123
# 116   Afghanistan        146                  2.40        149
#
#      2021 Happiness Score  2020 Rank  2020 Happiness Score  2019 Rank  \
# 0                    7.84          1                  7.81          1
# 1                    7.62          2                  7.65          2
# 2                    7.55          4                  7.50          4
# 3                    7.57          3                  7.56          6
# 4                    7.46          6                  7.45          5
# ..                    ...        ...                   ...        ...
# 112                  3.62        148                  3.48        153
# 113                  3.85        139                  3.93        129
# 114                  3.14        151                  3.30        146
# 115                  4.58        111                  4.77         91
# 116                  2.52        153                  2.57        154
#
#      2019 Happiness Score  2018 Rank  2018 Happiness Score  2017 Rank  \
# 0                    7.77          1                  7.63          5
# 1                    7.60          3                  7.56          2
# 2                    7.49          4                  7.50          3
# 3                    7.48          5                  7.49          4
# 4                    7.49          6                  7.44          6
# ..                    ...        ...                   ...        ...
# 112                  3.23        153                  3.30        153
# 113                  4.37        113                  4.57        106
# 114                  3.66        144                  3.69        138
# 115                  5.20         80                  5.36         88
# 116                  3.20        145                  3.63        141
#
#      2017 Happiness Score  2016 Rank  2016 Happiness Score  2015 Rank  \
# 0                    7.47          5                  7.41          6
# 1                    7.52          1                  7.53          3
# 2                    7.50          3                  7.50          2
# 3                    7.49          2                  7.51          1
# 4                    7.38          7                  7.34          7
# ..                    ...        ...                   ...        ...
# 112                  3.35        149                  3.67        146
# 113                  4.71        111                  4.64        123
# 114                  3.88        131                  4.19        115
# 115                  5.22         93                  5.13        103
# 116                  3.79        154                  3.36        153
#
#      2015 Happiness Score
# 0                    7.41
# 1                    7.53
# 2                    7.56
# 3                    7.59
# 4                    7.38
# ..                    ...
# 112                  3.78
# 113                  4.51
# 114                  4.61
# 115                  4.84
# 116                  3.58
#
# [117 rows x 17 columns]

# %%
#making initial map with lines around country to fill later
countries_geojson = gmaps.geojson_geometries.load_geometry('countries')
fig = gmaps.figure()
happy_layer=gmaps.geojson_layer(countries_geojson)
# fig.add_layer(happy_layer)
# fig

# %%
# need to get the min and the max of happiness
# happy_df=happy_df.set_index(["Country"])

# %%
happy_df.dtypes
# Out:
# Country                  object
# 2022 Rank                 int64
# 2022 Happiness Score    float64
# 2021 Rank                 int64
# 2021 Happiness Score    float64
# 2020 Rank                 int64
# 2020 Happiness Score    float64
# 2019 Rank                 int64
# 2019 Happiness Score    float64
# 2018 Rank                 int64
# 2018 Happiness Score    float64
# 2017 Rank                 int64
# 2017 Happiness Score    float64
# 2016 Rank                 int64
# 2016 Happiness Score    float64
# 2015 Rank                 int64
# 2015 Happiness Score    float64
# dtype: object

# %%
happy_col=happy_df["2021 Happiness Score"]
h_range=[]

for x in happy_col:
    happ_conv= x / 10
    h_range.append(happ_conv)
    
# happy_range=happ_max-happ_min

happy_df['Happiness Range 2021'] = h_range
happy_df
# happy_df["Country"].values
# Out:
#           Country  2022 Rank  2022 Happiness Score  2021 Rank  \
# 0         Finland          1                  7.82          1
# 1         Denmark          2                  7.64          2
# 2         Iceland          3                  7.56          4
# 3     Switzerland          4                  7.51          3
# 4     Netherlands          5                  7.42          5
# ..            ...        ...                   ...        ...
# 112      Tanzania        139                  3.70        142
# 113  Sierra Leone        140                  3.57        138
# 114      Zimbabwe        144                  3.00        148
# 115       Lebanon        145                  2.96        123
# 116   Afghanistan        146                  2.40        149
#
#      2021 Happiness Score  2020 Rank  2020 Happiness Score  2019 Rank  \
# 0                    7.84          1                  7.81          1
# 1                    7.62          2                  7.65          2
# 2                    7.55          4                  7.50          4
# 3                    7.57          3                  7.56          6
# 4                    7.46          6                  7.45          5
# ..                    ...        ...                   ...        ...
# 112                  3.62        148                  3.48        153
# 113                  3.85        139                  3.93        129
# 114                  3.14        151                  3.30        146
# 115                  4.58        111                  4.77         91
# 116                  2.52        153                  2.57        154
#
#      2019 Happiness Score  2018 Rank  2018 Happiness Score  2017 Rank  \
# 0                    7.77          1                  7.63          5
# 1                    7.60          3                  7.56          2
# 2                    7.49          4                  7.50          3
# 3                    7.48          5                  7.49          4
# 4                    7.49          6                  7.44          6
# ..                    ...        ...                   ...        ...
# 112                  3.23        153                  3.30        153
# 113                  4.37        113                  4.57        106
# 114                  3.66        144                  3.69        138
# 115                  5.20         80                  5.36         88
# 116                  3.20        145                  3.63        141
#
#      2017 Happiness Score  2016 Rank  2016 Happiness Score  2015 Rank  \
# 0                    7.47          5                  7.41          6
# 1                    7.52          1                  7.53          3
# 2                    7.50          3                  7.50          2
# 3                    7.49          2                  7.51          1
# 4                    7.38          7                  7.34          7
# ..                    ...        ...                   ...        ...
# 112                  3.35        149                  3.67        146
# 113                  4.71        111                  4.64        123
# 114                  3.88        131                  4.19        115
# 115                  5.22         93                  5.13        103
# 116                  3.79        154                  3.36        153
#
#      2015 Happiness Score  Happiness Range 2021
# 0                    7.41                 0.784
# 1                    7.53                 0.762
# 2                    7.56                 0.755
# 3                    7.59                 0.757
# 4                    7.38                 0.746
# ..                    ...                   ...
# 112                  3.78                 0.362
# 113                  4.51                 0.385
# 114                  4.61                 0.314
# 115                  4.84                 0.458
# 116                  3.58                 0.252
#
# [117 rows x 18 columns]

# %%
# We will need to scale the Happiness values to lie between 0 and 1, this sets up for color ranges below
happ_max1=happy_df["Happiness Range 2021"].max()
happ_min1=happy_df["Happiness Range 2021"].min()
hap_range=happ_max1-happ_min1
inferno2= inferno.reversed()

def calculate_color(h_range):
    
#     Convert the happiness coefficient to a color

    # make happiness a number between 0 and 1
    normalized_range = (h_range - happ_min1) / hap_range

    # invert happiness so that high inequality gives dark color
    inverse_hap = 1.0 - normalized_range

    # transform the happiness coefficient to a matplotlib color
    mpl_color = inferno2(inverse_hap)

    # transform from a matplotlib color to a valid CSS color
    gmaps_color = to_hex(mpl_color, keep_alpha=False)

    return gmaps_color

# %%
colors = []
for feature in countries_geojson['features']:
    country_name = feature['properties']['name']
    print(country_name)
    try:
        h_range = happy_df.loc[happy_df["Country"]==country_name]["Happiness Range 2021"].values
        print(h_range)
        color = calculate_color(h_range)
        print(color)
    except KeyError:
        # no happyy score for that country: return default color
        color = (0, 0, 0, 0.3)
        print(country_name+" not available")
    except ValueError: 
        color = (0, 0, 0, 0.3)
        
    print(color)    
    colors.append(color)
colors
# Out:
# Afghanistan
# [0.252]
# #000004
# #000004
# Angola
# []
# (0, 0, 0, 0.3)
# Albania
# [0.512]
# #b73557
# #b73557
# Aland
# []
# (0, 0, 0, 0.3)
# Andorra
# []
# (0, 0, 0, 0.3)
# United Arab Emirates
# [0.656]
# #fa9207
# #fa9207
# Argentina
# [0.593]
# #e8602d
# #e8602d
# Armenia
# [0.528]
# #c13a50
# #c13a50
# American Samoa
# []
# (0, 0, 0, 0.3)
# Antarctica
# []
# (0, 0, 0, 0.3)
# French Southern and Antarctic Lands
# []
# (0, 0, 0, 0.3)
# Antigua and Barbuda
# []
# (0, 0, 0, 0.3)
# Australia
# [0.718]
# #f9cb35
# #f9cb35
# Austria
# [0.727]
# #f7d340
# #f7d340
# Azerbaijan
# []
# (0, 0, 0, 0.3)
# Burundi
# []
# (0, 0, 0, 0.3)
# Belgium
# [0.683]
# #fcaa0f
# #fcaa0f
# Benin
# [0.504]
# #b1325a
# #b1325a
# Burkina Faso
# [0.483]
# #a22b62
# #a22b62
# Bangladesh
# [0.503]
# #b0315b
# #b0315b
# Bulgaria
# [0.527]
# #c13a50
# #c13a50
# Bahrain
# [0.665]
# #fb9906
# #fb9906
# The Bahamas
# []
# (0, 0, 0, 0.3)
# Bosnia and Herzegovina
# [0.581]
# #e25734
# #e25734
# Belarus
# []
# (0, 0, 0, 0.3)
# Belize
# []
# (0, 0, 0, 0.3)
# Bolivia
# [0.572]
# #dd513a
# #dd513a
# Brazil
# [0.633]
# #f67e14
# #f67e14
# Barbados
# []
# (0, 0, 0, 0.3)
# Brunei
# []
# (0, 0, 0, 0.3)
# Bhutan
# []
# (0, 0, 0, 0.3)
# Botswana
# []
# (0, 0, 0, 0.3)
# Central African Republic
# []
# (0, 0, 0, 0.3)
# Canada
# [0.71]
# #fac42a
# #fac42a
# Switzerland
# [0.757]
# #f1ef75
# #f1ef75
# Chile
# [0.617]
# #f1711f
# #f1711f
# China
# [0.534]
# #c63d4d
# #c63d4d
# Ivory Coast
# [0.531]
# #c43c4e
# #c43c4e
# Cameroon
# [0.514]
# #b93556
# #b93556
# Cyprus No Mans Area
# []
# (0, 0, 0, 0.3)
# Democratic Republic of the Congo
# []
# (0, 0, 0, 0.3)
# Republic of Congo
# []
# (0, 0, 0, 0.3)
# Colombia
# [0.601]
# #eb6429
# #eb6429
# Comoros
# []
# (0, 0, 0, 0.3)
# Cape Verde
# []
# (0, 0, 0, 0.3)
# Costa Rica
# [0.707]
# #fac026
# #fac026
# Cuba
# []
# (0, 0, 0, 0.3)
# Curaçao
# []
# (0, 0, 0, 0.3)
# Cayman Islands
# []
# (0, 0, 0, 0.3)
# Northern Cyprus
# []
# (0, 0, 0, 0.3)
# Cyprus
# [0.622]
# #f3761b
# #f3761b
# Czech Republic
# []
# (0, 0, 0, 0.3)
# Germany
# [0.716]
# #f9c932
# #f9c932
# Djibouti
# []
# (0, 0, 0, 0.3)
# Dominica
# []
# (0, 0, 0, 0.3)
# Denmark
# [0.762]
# #f2f27d
# #f2f27d
# Dominican Republic
# [0.554]
# #d34743
# #d34743
# Algeria
# [0.489]
# #a62d60
# #a62d60
# Ecuador
# [0.576]
# #df5337
# #df5337
# Egypt
# [0.428]
# #771c6d
# #771c6d
# Eritrea
# []
# (0, 0, 0, 0.3)
# Spain
# [0.649]
# #f98c0a
# #f98c0a
# Estonia
# [0.619]
# #f1731d
# #f1731d
# Ethiopia
# [0.428]
# #771c6d
# #771c6d
# Finland
# [0.784]
# #fcffa4
# #fcffa4
# Fiji
# []
# (0, 0, 0, 0.3)
# Falkland Islands
# []
# (0, 0, 0, 0.3)
# France
# [0.669]
# #fb9d07
# #fb9d07
# Faroe Islands
# []
# (0, 0, 0, 0.3)
# Federated States of Micronesia
# []
# (0, 0, 0, 0.3)
# Gabon
# [0.485]
# #a32c61
# #a32c61
# United Kingdom
# [0.706]
# #fac026
# #fac026
# Georgia
# [0.489]
# #a62d60
# #a62d60
# Ghana
# [0.509]
# #b43359
# #b43359
# Guinea
# [0.498]
# #ad305d
# #ad305d
# Gambia
# []
# (0, 0, 0, 0.3)
# Guinea Bissau
# []
# (0, 0, 0, 0.3)
# Equatorial Guinea
# []
# (0, 0, 0, 0.3)
# Greece
# [0.572]
# #dd513a
# #dd513a
# Grenada
# []
# (0, 0, 0, 0.3)
# Greenland
# []
# (0, 0, 0, 0.3)
# Guatemala
# []
# (0, 0, 0, 0.3)
# Guam
# []
# (0, 0, 0, 0.3)
# Guyana
# []
# (0, 0, 0, 0.3)
# Hong Kong S.A.R.
# []
# (0, 0, 0, 0.3)
# Heard Island and McDonald Islands
# []
# (0, 0, 0, 0.3)
# Honduras
# [0.592]
# #e75e2e
# #e75e2e
# Croatia
# [0.588]
# #e55c30
# #e55c30
# Haiti
# []
# (0, 0, 0, 0.3)
# Hungary
# [0.599]
# #ea632a
# #ea632a
# Indonesia
# [0.534]
# #c63d4d
# #c63d4d
# Isle of Man
# []
# (0, 0, 0, 0.3)
# India
# [0.382]
# #540f6d
# #540f6d
# Ireland
# [0.708]
# #fac228
# #fac228
# Iran
# [0.472]
# #982766
# #982766
# Iraq
# [0.485]
# #a32c61
# #a32c61
# Iceland
# [0.755]
# #f1ed71
# #f1ed71
# Israel
# [0.716]
# #f9c932
# #f9c932
# Italy
# [0.648]
# #f98b0b
# #f98b0b
# Jamaica
# [0.631]
# #f57d15
# #f57d15
# Jordan
# [0.439]
# #7f1e6c
# #7f1e6c
# Japan
# [0.594]
# #e8602d
# #e8602d
# Baykonur Cosmodrome
# []
# (0, 0, 0, 0.3)
# Siachen Glacier
# []
# (0, 0, 0, 0.3)
# Kazakhstan
# [0.615]
# #f06f20
# #f06f20
# Kenya
# [0.461]
# #902568
# #902568
# Kyrgyzstan
# [0.574]
# #de5238
# #de5238
# Cambodia
# [0.483]
# #a22b62
# #a22b62
# Kiribati
# []
# (0, 0, 0, 0.3)
# Saint Kitts and Nevis
# []
# (0, 0, 0, 0.3)
# South Korea
# [0.584]
# #e35933
# #e35933
# Kosovo
# [0.637]
# #f78212
# #f78212
# Kuwait
# []
# (0, 0, 0, 0.3)
# Laos
# []
# (0, 0, 0, 0.3)
# Lebanon
# [0.458]
# #8f2469
# #8f2469
# Liberia
# []
# (0, 0, 0, 0.3)
# Libya
# []
# (0, 0, 0, 0.3)
# Saint Lucia
# []
# (0, 0, 0, 0.3)
# Liechtenstein
# []
# (0, 0, 0, 0.3)
# Sri Lanka
# [0.432]
# #7a1d6d
# #7a1d6d
# Lesotho
# []
# (0, 0, 0, 0.3)
# Lithuania
# [0.626]
# #f37819
# #f37819
# Luxembourg
# []
# (0, 0, 0, 0.3)
# Latvia
# [0.603]
# #eb6628
# #eb6628
# Morocco
# [0.492]
# #a82e5f
# #a82e5f
# Moldova
# [0.577]
# #e05536
# #e05536
# Madagascar
# []
# (0, 0, 0, 0.3)
# Mexico
# [0.632]
# #f57d15
# #f57d15
# Macedonia
# []
# (0, 0, 0, 0.3)
# Mali
# [0.472]
# #982766
# #982766
# Malta
# [0.66]
# #fb9606
# #fb9606
# Myanmar
# [0.443]
# #82206c
# #82206c
# Montenegro
# [0.558]
# #d54a41
# #d54a41
# Mongolia
# [0.568]
# #db503b
# #db503b
# Northern Mariana Islands
# []
# (0, 0, 0, 0.3)
# Mozambique
# []
# (0, 0, 0, 0.3)
# Mauritania
# []
# (0, 0, 0, 0.3)
# Mauritius
# [0.605]
# #ec6726
# #ec6726
# Malawi
# [0.36]
# #420a68
# #420a68
# Malaysia
# [0.538]
# #c83f4b
# #c83f4b
# Namibia
# []
# (0, 0, 0, 0.3)
# New Caledonia
# []
# (0, 0, 0, 0.3)
# Niger
# []
# (0, 0, 0, 0.3)
# Nigeria
# [0.476]
# #9b2964
# #9b2964
# Nicaragua
# [0.597]
# #ea632a
# #ea632a
# Niue
# []
# (0, 0, 0, 0.3)
# Netherlands
# [0.746]
# #f3e55d
# #f3e55d
# Norway
# [0.739]
# #f4df53
# #f4df53
# Nepal
# [0.527]
# #c13a50
# #c13a50
# New Zealand
# [0.728]
# #f6d543
# #f6d543
# Oman
# []
# (0, 0, 0, 0.3)
# Pakistan
# [0.493]
# #a82e5f
# #a82e5f
# Panama
# [0.618]
# #f1731d
# #f1731d
# Peru
# [0.584]
# #e35933
# #e35933
# Philippines
# [0.588]
# #e55c30
# #e55c30
# Palau
# []
# (0, 0, 0, 0.3)
# Papua New Guinea
# []
# (0, 0, 0, 0.3)
# Poland
# [0.617]
# #f1711f
# #f1711f
# Puerto Rico
# []
# (0, 0, 0, 0.3)
# North Korea
# []
# (0, 0, 0, 0.3)
# Portugal
# [0.593]
# #e8602d
# #e8602d
# Paraguay
# [0.565]
# #d94d3d
# #d94d3d
# Palestine
# []
# (0, 0, 0, 0.3)
# French Polynesia
# []
# (0, 0, 0, 0.3)
# Qatar
# []
# (0, 0, 0, 0.3)
# Romania
# [0.614]
# #f06f20
# #f06f20
# Russia
# [0.548]
# #cf4446
# #cf4446
# Rwanda
# []
# (0, 0, 0, 0.3)
# Western Sahara
# []
# (0, 0, 0, 0.3)
# Saudi Arabia
# [0.649]
# #f98c0a
# #f98c0a
# Sudan
# []
# (0, 0, 0, 0.3)
# South Sudan
# []
# (0, 0, 0, 0.3)
# Senegal
# [0.513]
# #b73557
# #b73557
# Singapore
# [0.638]
# #f78212
# #f78212
# South Georgia and South Sandwich Islands
# []
# (0, 0, 0, 0.3)
# Saint Helena
# []
# (0, 0, 0, 0.3)
# Solomon Islands
# []
# (0, 0, 0, 0.3)
# Sierra Leone
# [0.385]
# #550f6d
# #550f6d
# El Salvador
# [0.606]
# #ed6925
# #ed6925
# Somaliland
# []
# (0, 0, 0, 0.3)
# Somalia
# []
# (0, 0, 0, 0.3)
# Saint Pierre and Miquelon
# []
# (0, 0, 0, 0.3)
# Republic of Serbia
# []
# (0, 0, 0, 0.3)
# Sao Tome and Principe
# []
# (0, 0, 0, 0.3)
# Suriname
# []
# (0, 0, 0, 0.3)
# Slovakia
# [0.633]
# #f67e14
# #f67e14
# Slovenia
# [0.646]
# #f8890c
# #f8890c
# Sweden
# [0.736]
# #f5db4c
# #f5db4c
# Swaziland
# []
# (0, 0, 0, 0.3)
# Syria
# []
# (0, 0, 0, 0.3)
# Chad
# []
# (0, 0, 0, 0.3)
# Togo
# [0.411]
# #6a176e
# #6a176e
# Thailand
# [0.598]
# #ea632a
# #ea632a
# Tajikistan
# [0.547]
# #ce4347
# #ce4347
# Turkmenistan
# []
# (0, 0, 0, 0.3)
# East Timor
# []
# (0, 0, 0, 0.3)
# Tonga
# []
# (0, 0, 0, 0.3)
# Trinidad and Tobago
# []
# (0, 0, 0, 0.3)
# Tunisia
# [0.46]
# #902568
# #902568
# Turkey
# [0.495]
# #a92e5e
# #a92e5e
# Taiwan
# []
# (0, 0, 0, 0.3)
# United Republic of Tanzania
# []
# (0, 0, 0, 0.3)
# Uganda
# [0.464]
# #932667
# #932667
# Ukraine
# [0.488]
# #a52c60
# #a52c60
# Uruguay
# [0.643]
# #f8870e
# #f8870e
# United States of America
# [0.695]
# #fbb61a
# #fbb61a
# Uzbekistan
# [0.618]
# #f1731d
# #f1731d
# Saint Vincent and the Grenadines
# []
# (0, 0, 0, 0.3)
# Venezuela
# [0.489]
# #a62d60
# #a62d60
# United States Virgin Islands
# []
# (0, 0, 0, 0.3)
# Vietnam
# [0.541]
# #cb4149
# #cb4149
# Vanuatu
# []
# (0, 0, 0, 0.3)
# Samoa
# []
# (0, 0, 0, 0.3)
# Yemen
# []
# (0, 0, 0, 0.3)
# South Africa
# [0.496]
# #ab2f5e
# #ab2f5e
# Zambia
# [0.407]
# #67166e
# #67166e
# Zimbabwe
# [0.314]
# #1c0c43
# #1c0c43
# ['#000004',
#  (0, 0, 0, 0.3),
#  '#b73557',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fa9207',
#  '#e8602d',
#  '#c13a50',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f9cb35',
#  '#f7d340',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fcaa0f',
#  '#b1325a',
#  '#a22b62',
#  '#b0315b',
#  '#c13a50',
#  '#fb9906',
#  (0, 0, 0, 0.3),
#  '#e25734',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#dd513a',
#  '#f67e14',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fac42a',
#  '#f1ef75',
#  '#f1711f',
#  '#c63d4d',
#  '#c43c4e',
#  '#b93556',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#eb6429',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fac026',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f3761b',
#  (0, 0, 0, 0.3),
#  '#f9c932',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f2f27d',
#  '#d34743',
#  '#a62d60',
#  '#df5337',
#  '#771c6d',
#  (0, 0, 0, 0.3),
#  '#f98c0a',
#  '#f1731d',
#  '#771c6d',
#  '#fcffa4',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#fb9d07',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#a32c61',
#  '#fac026',
#  '#a62d60',
#  '#b43359',
#  '#ad305d',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#dd513a',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#e75e2e',
#  '#e55c30',
#  (0, 0, 0, 0.3),
#  '#ea632a',
#  '#c63d4d',
#  (0, 0, 0, 0.3),
#  '#540f6d',
#  '#fac228',
#  '#982766',
#  '#a32c61',
#  '#f1ed71',
#  '#f9c932',
#  '#f98b0b',
#  '#f57d15',
#  '#7f1e6c',
#  '#e8602d',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f06f20',
#  '#902568',
#  '#de5238',
#  '#a22b62',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#e35933',
#  '#f78212',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#8f2469',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#7a1d6d',
#  (0, 0, 0, 0.3),
#  '#f37819',
#  (0, 0, 0, 0.3),
#  '#eb6628',
#  '#a82e5f',
#  '#e05536',
#  (0, 0, 0, 0.3),
#  '#f57d15',
#  (0, 0, 0, 0.3),
#  '#982766',
#  '#fb9606',
#  '#82206c',
#  '#d54a41',
#  '#db503b',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#ec6726',
#  '#420a68',
#  '#c83f4b',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#9b2964',
#  '#ea632a',
#  (0, 0, 0, 0.3),
#  '#f3e55d',
#  '#f4df53',
#  '#c13a50',
#  '#f6d543',
#  (0, 0, 0, 0.3),
#  '#a82e5f',
#  '#f1731d',
#  '#e35933',
#  '#e55c30',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f1711f',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#e8602d',
#  '#d94d3d',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f06f20',
#  '#cf4446',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f98c0a',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#b73557',
#  '#f78212',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#550f6d',
#  '#ed6925',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#f67e14',
#  '#f8890c',
#  '#f5db4c',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#6a176e',
#  '#ea632a',
#  '#ce4347',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#902568',
#  '#a92e5e',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#932667',
#  '#a52c60',
#  '#f8870e',
#  '#fbb61a',
#  '#f1731d',
#  (0, 0, 0, 0.3),
#  '#a62d60',
#  (0, 0, 0, 0.3),
#  '#cb4149',
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  (0, 0, 0, 0.3),
#  '#ab2f5e',
#  '#67166e',
#  '#1c0c43']

# %%
fig = gmaps.figure()
happy_layer2 = gmaps.geojson_layer(
    countries_geojson,
    fill_color=colors,
    stroke_color=colors,
    fill_opacity=0.8)
fig.add_layer(happy_layer2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
